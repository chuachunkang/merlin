# %%
#### Code Chunk 1 ####
# run once whenever you restart
import pandas as pd
pd.options.mode.chained_assignment = None 
import numpy as np
import qgrid

# %% [markdown]
# #### 899 companies in total for FY2019 FS

# %%
df = pd.read_pickle('output.pkl')

# %%
df['filename'].values
# Out:
# array(['196700147N_KEPPEL FELS LIMITED_C200290212_2FY19.pdf',
#        '196800180M_ST ENGINEERING MARINE LTD._C200305968_1FY19.pdf',
#        '196900111W_MAMMOET (S) PTE LTD_C200391028_1FY19.pdf',
#        '197000594D_KEPPEL SHIPYARD LIMITED_C200385379_2FY19.pdf',
#        '197201195Z_DOLPHIN SHIPPING COMPANY PRIVATE LIMITED._C200251848_1FY19.pdf',
#        '197600165Z_PENGUIN INTERNATIONAL LIMITED_C200324816_1FY19.pdf',
#        '197600666D_CH OFFSHORE LTD._C200320291_1FY19.pdf',
#        '197701384D_SEA GLORY PRIVATE LIMITED_C200490255_1FY19.pdf',
#        '197701532G_OXALIS SHIPPING CO. PTE. LTD._C200393057_1FY19.pdf',
#        '197800703R_KIM HENG MARINE & OILFIELD PTE LTD_C200659198_1FY19.pdf',
#        '197900037Z_LINGCO MARINE SERVICES PTE LTD_C210043303_2FY19.pdf',
#        '197900185R_REGIONAL CONTAINER LINES PTE. LTD._C200431350_1FY19.pdf',
#        '198004003R_LINGCOTUG PTE. LTD._C210043115_2FY19.pdf',
# ...

# %%
coy_num = 0
print(df['filename'][coy_num], df['denomination'][coy_num])
df['table'][coy_num]
# Out:
# 196700147N_KEPPEL FELS LIMITED_C200290212_2FY19.pdf S$'000
#                            0            1          2        3          4  \
# 0                               buildings        and            work-in-
# 1                             and wharves  equipment  Vessels   progress
# 2                                   $’000      $’000    $’000      $’000
# 3                      Cost:
# 4          At 1 January 2018      228,526    371,411   60,815    146,655
# 5                  Additions            -         81        -     69,485
# 6                  Disposals            -    (2,431)  (7,672)    (4,348)
# 7          Reclassifications            -     23,804        -   (23,804)
# 8        At 31 December 2018      228,526    392,865   53,143    187,988
# 9                  Additions            -      5,554        -     25,938
# 10                 Disposals            -      (337)    (210)          -
# 11         Reclassifications        3,085    (2,371)  184,778  (185,492)
# ...
