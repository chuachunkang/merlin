# %%
#### Code Chunk 1 ####
# run once whenever you restart
import pandas as pd
pd.options.mode.chained_assignment = None 
import numpy as np
import qgrid

# %% [markdown]
# #### 899 companies in total for FY2019 FS

# %%
#### Code Chunk 2 ####
# run once whenever you restart
df = pd.read_csv(r'C:\Users\Chua\Desktop\tesseract\srs_2019\output.csv', sep = ' ')
df.shape
# Out:
# (899, 6)

# %% [markdown]
# #### To interact with the table below,  filter by "filename", then run Code Chunk 4 once by pressing Ctrl+Enter to render table

# %%
#### Code Chunk 3 ####
# run once whenever you restart
widget = qgrid.show_grid(df, show_toolbar=True)
widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
#### Code Chunk 4 ####
widget.get_changed_df()['table'][0].split('\n')
# Out:
# ['                           0            1          2        3          4  \\',
#  '0                               buildings        and            work-in-   ',
#  '1                             and wharves  equipment  Vessels   progress   ',
#  '2                                   $’000      $’000    $’000      $’000   ',
#  '3                      Cost:                                               ',
#  '4          At 1 January 2018      228,526    371,411   60,815    146,655   ',
#  '5                  Additions            -         81        -     69,485   ',
#  '6                  Disposals            -    (2,431)  (7,672)    (4,348)   ',
#  '7          Reclassifications            -     23,804        -   (23,804)   ',
#  '8        At 31 December 2018      228,526    392,865   53,143    187,988   ',
#  '9                  Additions            -      5,554        -     25,938   ',
#  '10                 Disposals            -      (337)    (210)          -   ',
# ...
